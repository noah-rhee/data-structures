# %% [markdown]
# Created by Junyeong Ahn.
#
# Most of slides are borrowed from [CSE2010] Data Structures Department of Data Science, HYU.

# %% [markdown]
# ## Week 3 - Linked List

# %%
def add(x, y):
    return x + y

    print(add(1, 2))

# %%
class ListNode():
    self.next = next
    self.val = ValueError
    
    head = ListNode(1)

# %%
x = [1, 2, 3, 4, 5]
x[3] # O(?)

x.append(8) # 준성: O(1) / 윤성: O(1)
del x[3] # 준: O(1)  윤: O(1)

if 3 in x: # 준: O(n) 윤: O(n)

# %% [markdown]
# 🚨 Difficult Chapter Alert 🚨

# %% [markdown]
# ### Linked List

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class ListNode:
    def __init__(self, val = 0, next=None):
        self.val = val # real data
        self.next = next # pointer to the next element (=node)


first = ListNode("2")




# first.next = ListNode("3")
# first.next.next = ListNode("4")
# first.next.next.next = ListNode("5")


# first.next = ListNode("3")
# first = first.next # move forward
# first.next = ListNode("4")
# first = first.next 


boss = ListNode("a") # boss는 LinsNode class의 '특정' object를 가르킨다.ㄴ
worker = boss # 시작점의 복사본
for i in ["b", "c", "D", "e"]:
    worker.next = ListNode(i)
    worker = worker.next







x = [1 , 3, 4, 5, 7]
y = 10

x[3] = y
y = x[3]
# Out:
# 'a'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ```Head``` means the leading node.
#
# In most of cases, you are only given ```head``` node. Starting from the node, you need to go next of it by ```next``` instance variable. Then go next of that node again, one by one..

# %%
class ListNode:
    def __init__(self, val = 0, next=None):
        self.val = val # real data
        self.next = next # pointer to the next element (=node)


head = ListNode(1)
head.next = ListNode(2)

# %% [markdown]
# In the example above, ```head``` is an object of ListNode class that has an instance variable ```self.next```. All I have to do is store the next node in the instance variable. Again and again!

# %%
# head = ListNode(1)
# head.next = ListNode(2) 
# head.next.next = ListNode(3)
# head.next.next.next = ListNode(4)
# ...



head = ListNode(1)
current_node = head # deep copy (head랑 current_node랑 not synchronized)
for i in range(2, 11):
    current_node.next = ListNode(i) 
    current_node = current_node.next # ???????



current_node = head # for traversing
for i in range(1, 11):
    
    if current_node.val == 7:
        print("hurray")
    current_node = current_node.next



# for i in range(2, 11):
#     head.next = ListNode(i)
#     head = head.next # ???????




# current_node.val
# current_node.next

# head.val
# Out:
# hurray

# %% [markdown]
# By default, ```self.next``` is set to None since we only provide one argument (for ```self.value```) with ListNode object creation:
#
# ```python
# def __init__(self, val = 0, next=None):
# ```
#
#
# <br><br>
#
#
# Therefore, the last node is supposed to be pointing at ```None```(nothing):

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Four basic operations:
#
# - **Traversing** the linked list
# - **Searching** for an item in the linked list
# - **Inserting** a node to the linked list
# - **Deleting** a node from the linked list

# %% [markdown]
# ### Traversing

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def traverse(head):
    current = head  
    while current: 
        print(current.val, end=" -> ")
        current = current.next  
    print("None")

# %%
...
head =
current = head 

while ..
    


#######
current = head

while current: # None이 될때까지? <- linked list의 tail의 .next = None
    print(current.val, end = " -> ")
    current = current.next

#######
current = head
while current: # None이 될때까지? <- linked list의 tail의 .next = None
    if current.val == '3':
        return True
    print(current.val, end = " -> ")
    current = current.next

return False

# %% [markdown]
# ### Search

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def search(head, target):
    current = head  
    while current:
        if current.val == target: 
            return True  
        current = current.next 
    return False

# %%
class ListNode: # node (not list)
    def __init__(self, data, next = None): # none: 일단 다음게 뭐가 올지 모르니까, 포도알 하나를 만들 때 값만 줄 수 있게
        self.data = data 
        self.next = next

head = ListNode(1)

for i in [1, 3, 4, 6, 8]:
    head.next = ListNode(3) # 지금 node의 다음거를 지정해주는 동시에, 그 '다음거'를 생성을 해준다.
    head = head.next # fast forward

# %%
# implement list node class from scratch
# with that implementation create multiple objects and connect them to construct a linked list whose values range from 1-5
# traverse from the start to end  
class ListNode():
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next


def traverse(h):
    current = h
    while current:
        print(current.val)
        current = current.next
    print("None")

head = ListNode(1)
cursor = head

for i in [2, 3, 4, 5]:
    cursor.next = ListNode(i)
    cursor = cursor.next

traverse(head)
# Out:
# 1
# 2
# 3
# 4
# 5
# None

# %% [markdown]
# ### Inserstion

# %% [markdown]
# You have three choices:
#
# - 1. Insert a new node before the head (at the beginning)
# - 2. Insert a new node after the tail (at the end)
# - 3. Insert a new node at the middle (random location)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def insert_at_front(head, val):
    new_node = ListNode(val)  
    new_node.next = head 
    
    return new_node

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def insert_at_end(head, val):
    new_node = ListNode(val) # 맨 뒤에 붙이고 싶은 list node object 생성
    if not head:  # 내가 받은 head가 None일 경우
        return new_node
    
    ## travsere 시작
    current = head
    while current.next: # 한 칸 미래를 본다 (딱 마지막까지 도착!)
        current = current.next
    
    # traverse는 끝나고, 이제 그 마지막의 '다음'이 new_node가 된다고 말해주자.
    current.next = new_node  
    return head

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def insert_at_position(head, val, position):
    # 붙이는 위치가 맨 앞인 경우
    if position <= 1: 
        return insert_at_front(head, val)
    
    # 붙일 애 생성
    new_node = ListNode(val)
    current = head
    for _ in range(position - 2):  
        if not current.next: # move forward하려는 도중에 이미 linked list가 끝난 경우
            break  #그럼 move forward를 할 수가 없으니.. 멈춰
        current = current.next

    new_node.next = current.next  # 1. 
    current.next = new_node # 2.
    return head

# %% [markdown]
# ### Deletion

# %% [markdown]
# - 1. Delete the first node
# - 2. Delete the last node
# - 3. Delete an intermediate node

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def delete_from_front(head):
    if not head:  
        return None
    return head.next

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def delete_from_end(head):
    if not head.next:  
        return None
    
    current = head
    while current.next and current.next.next:  
        current = current.next
    current.next = None 
    return head

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def delete_by_value(head, target):
    if not head:  
        return None
    if head.val == target: 
        return head.next
    current = head # 노동자 생성

    while current.next:
        if current.next.val == target: 
            current.next = current.next.next  # 다음 하나(=지울거)를 건너뛰는 길을 새로 생성!
            return head
        current = current.next # move forward
    return head

# %% [markdown]
# ### Question!

# %% [markdown]
# Is there no way to delete certain node only given the current node?

# %%
head = ListNode(1)
head.next = ListNode(2)
head.next.next = ListNode(3)
head.next.next.next = ListNode(4)
head.next.next.next.next = ListNode(5)


head

# ListNode(3) 지우시오.

tmp = head.next.next

tmp.val = tmp.next.val

# %% [markdown]
# ### Arrays vs. Linked Lists

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Note

# %% [markdown]
# Going forward will be not that hard. But going backward will be very tough - you need to leave the footprints somewhere to keep track of them.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# That's where doubly linked lists come to play. Now we are able to delete a node without the previous node's address since we can freely go in bidirection.

# %% [markdown]
# Still, there are extra memories needed as you can see (two for each node).

# %% [markdown]
# ## Homework

# %% [markdown]
# Solve the following LeetCode questions and upload your solution code files as well.

# %% [markdown]
# ### Q1. [83. Remove Duplicates from Sorted List](https://leetcode.com/problems/remove-duplicates-from-sorted-list/description/?envType=problem-list-v2&envId=linked-list)

# %% [markdown]
# ### Q2. [206. Reverse Linked List](https://leetcode.com/problems/reverse-linked-list/description/?envType=problem-list-v2&envId=linked-list)

# %% [markdown]
# ## LinkedList build

# %%
class ListNode:
    def __init__(self, value, next = None):
        
        self.val = value
        self.next = next

head = ListNode("first")
cursor = head
for i in range(5):
    cursor.next = ListNode(i)
    cursor = cursor.next

# %% [markdown]
# ## 1. Insert

# %%
# beginning

new_node = ListNode("new")
new_node.next = head

# end

new_node = ListNode("new")
cursor = head

while cursor.next: # .next라는 instance variable (객체 변수)값이 None이다 라는 말은, tail까지 왔다는거
    cursor = cursor.next # move forward

## cursor: tail에 위치
cursor.next = new_node


# mid

new_node = ListNode("new")
cursor = head

for i in range(3):
    cursor = cursor.next

#1.
new_node.next = cursor.next # 새로운 node의 다음은, 지금 나의 다음이다
#2.
cursor.next = new_node

# %% [markdown]
# ## 2. Delete

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        current = head
        l = []
        if not head:
            return head
        while current:
            l.append(current.val)
            current = current.next
        print(l)
        l = list(reversed(l))
        print(l)
        new_head = ListNode(l[0])
        l.remove(l[0])
        for i in range(len(l)):
            new_head.next = ListNode(l[i])
            new_head = new_head.next
        print(new_head)

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def deleteDuplicates(self, head: Optional[ListNode]) -> Optional[ListNode]:
        l = []

        current = head
        if not current:
            return head
        if not current.next:
            return head
        if not current.next.next:
            if current.val == current.next.val:
                current.next.val = None
            return head
        if current.val == current.next.val:
            current.next = current.next.next
        while current.next and current.next.next:
            if current.next.val in l:
                current.next = current.next.next
            else:
                l.append(current.next.val)
            current = current.next
        if current.next.val in l:
            current.next = None
        return head

# %% [markdown]
# ## 3. Search
